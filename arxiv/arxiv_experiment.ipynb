# %%
from arxiv import run_experiment, plot_results

# %%
num_epochs = 200

# %%
gcn_curve = run_experiment(gnn_type="gcn", num_epochs=num_epochs)
# Out:
# Downloading https://snap.stanford.edu/ogb/data/nodeproppred/arxiv.zip
# Downloaded 0.08 GB: 100%|██████████| 81/81 [02:53<00:00,  2.14s/it]
# Extracting dataset/arxiv.zip
# Loading necessary files...
# This might take a while.
# 100%|██████████| 1/1 [00:00<00:00, 2294.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 43.63it/s]Processing graphs...
# Converting graphs into DGL objects...
# Saving...
#
# Started training gcn...
#
# ===== gcn epoch 10 =====
# Loss: 2.9075334072113037
# {'Train': {'acc': 0.29292618290979866}, 'Validation': {'acc': 0.29393603812208463}, 'Test': {'acc': 0.257226920148962}}
#
# ===== gcn epoch 20 =====
# Loss: 2.4188356399536133
# {'Train': {'acc': 0.40537271417732373}, 'Validation': {'acc': 0.3750125843149099}, 'Test': {'acc': 0.3157006769129478}}
#
# ===== gcn epoch 30 =====
# Loss: 2.135481834411621
# {'Train': {'acc': 0.4501050131403877}, 'Validation': {'acc': 0.40971173529313065}, 'Test': {'acc': 0.33619323910046706}}
#
# ===== gcn epoch 40 =====
# Loss: 1.9728010892868042
# {'Train': {'acc': 0.4942875050857149}, 'Validation': {'acc': 0.46363971945367294}, 'Test': {'acc': 0.37398925992222704}}
#
# ===== gcn epoch 50 =====
# Loss: 1.8381487131118774
# {'Train': {'acc': 0.5229214545694462}, 'Validation': {'acc': 0.48672774254169604}, 'Test': {'acc': 0.39011995144332656}}
#
# ===== gcn epoch 60 =====
# Loss: 1.7326704263687134
# {'Train': {'acc': 0.5412850089618544}, 'Validation': {'acc': 0.5013255478371758}, 'Test': {'acc': 0.4018270477131041}}
#
# ===== gcn epoch 70 =====
# Loss: 1.6629482507705688
# {'Train': {'acc': 0.5552720994930779}, 'Validation': {'acc': 0.5221316151548709}, 'Test': {'acc': 0.42040614776865626}}
#
# ===== gcn epoch 80 =====
# Loss: 1.5911675691604614
# {'Train': {'acc': 0.5658613826546882}, 'Validation': {'acc': 0.5281049699654351}, 'Test': {'acc': 0.4289858650700574}}
#
# ===== gcn epoch 90 =====
# Loss: 1.6038193702697754
# {'Train': {'acc': 0.5637941082679979}, 'Validation': {'acc': 0.5364945132386992}, 'Test': {'acc': 0.4520091352385655}}
#
# ===== gcn epoch 100 =====
# Loss: 1.5183273553848267
# {'Train': {'acc': 0.5791117317821445}, 'Validation': {'acc': 0.541628913721937}, 'Test': {'acc': 0.44200975248441454}}
#
# ===== gcn epoch 110 =====
# Loss: 1.4831054210662842
# {'Train': {'acc': 0.587402821609615}, 'Validation': {'acc': 0.5496493170911776}, 'Test': {'acc': 0.44931382836450423}}
#
# ===== gcn epoch 120 =====
# Loss: 1.4468836784362793
# {'Train': {'acc': 0.5936156409100406}, 'Validation': {'acc': 0.5572334642102084}, 'Test': {'acc': 0.4567002036911302}}
#
# ===== gcn epoch 130 =====
# Loss: 1.4317491054534912
# {'Train': {'acc': 0.5948692009104805}, 'Validation': {'acc': 0.5543139031511125}, 'Test': {'acc': 0.4555480114396231}}
#
# ===== gcn epoch 140 =====
# Loss: 1.4034026861190796
# {'Train': {'acc': 0.6028963833694373}, 'Validation': {'acc': 0.567636497869056}, 'Test': {'acc': 0.46581486739501676}}
#
# ===== gcn epoch 150 =====
# Loss: 1.379028081893921
# {'Train': {'acc': 0.6070089398621084}, 'Validation': {'acc': 0.5667304271955435}, 'Test': {'acc': 0.4651153220994589}}
#
# ===== gcn epoch 160 =====
# Loss: 1.3583037853240967
# {'Train': {'acc': 0.611891226179611}, 'Validation': {'acc': 0.5711936642169201}, 'Test': {'acc': 0.4713083554513096}}
#
# ===== gcn epoch 170 =====
# Loss: 1.3482741117477417
# {'Train': {'acc': 0.6145193037243928}, 'Validation': {'acc': 0.5677371723883352}, 'Test': {'acc': 0.46569141822521243}}
#
# ===== gcn epoch 180 =====
# Loss: 1.3276758193969727
# {'Train': {'acc': 0.6189397521469964}, 'Validation': {'acc': 0.5787106949897648}, 'Test': {'acc': 0.4834886735386705}}
#
# ===== gcn epoch 190 =====
# Loss: 1.3083895444869995
# {'Train': {'acc': 0.6219856830252581}, 'Validation': {'acc': 0.5714285714285714}, 'Test': {'acc': 0.46980639055202356}}
#
# ===== gcn epoch 200 =====
# Loss: 1.2953078746795654
# {'Train': {'acc': 0.6248226872367799}, 'Validation': {'acc': 0.5770999026812981}, 'Test': {'acc': 0.47865358105466743}}
#
# Finished training gcn .

# %%
sage_curve = run_experiment(gnn_type="sage", num_epochs=num_epochs)
# Out:
# Started training sage...
#
# ===== sage epoch 10 =====
# Loss: 2.860936164855957
# {'Train': {'acc': 0.29096886992665577}, 'Validation': {'acc': 0.3223933689049968}, 'Test': {'acc': 0.3091578709133181}}
#
# ===== sage epoch 20 =====
# Loss: 2.1902213096618652
# {'Train': {'acc': 0.4224277278675185}, 'Validation': {'acc': 0.43464545790127185}, 'Test': {'acc': 0.3844412896323272}}
#
# ===== sage epoch 30 =====
# Loss: 1.9186753034591675
# {'Train': {'acc': 0.48310443034494893}, 'Validation': {'acc': 0.4899157689855364}, 'Test': {'acc': 0.44083698537127336}}
#
# ===== sage epoch 40 =====
# Loss: 1.7089948654174805
# {'Train': {'acc': 0.5256045128160016}, 'Validation': {'acc': 0.5200845665961945}, 'Test': {'acc': 0.46665843672201307}}
#
# ===== sage epoch 50 =====
# Loss: 1.58846116065979
# {'Train': {'acc': 0.555228114931659}, 'Validation': {'acc': 0.5421322863183329}, 'Test': {'acc': 0.4875419212805794}}
#
# ===== sage epoch 60 =====
# Loss: 1.5145841836929321
# {'Train': {'acc': 0.5684124872169868}, 'Validation': {'acc': 0.5512936675727373}, 'Test': {'acc': 0.495545542456227}}
#
# ===== sage epoch 70 =====
# Loss: 1.4862669706344604
# {'Train': {'acc': 0.5750651521316018}, 'Validation': {'acc': 0.5644820295983086}, 'Test': {'acc': 0.5044133078205049}}
#
# ===== sage epoch 80 =====
# Loss: 1.4311507940292358
# {'Train': {'acc': 0.5887443507328928}, 'Validation': {'acc': 0.5714956877747576}, 'Test': {'acc': 0.5119437071785692}}
#
# ===== sage epoch 90 =====
# Loss: 1.3997210264205933
# {'Train': {'acc': 0.5937585907346521}, 'Validation': {'acc': 0.5711265478707339}, 'Test': {'acc': 0.5029524926444869}}
#
# ===== sage epoch 100 =====
# Loss: 1.3716148138046265
# {'Train': {'acc': 0.6034022058257552}, 'Validation': {'acc': 0.5805228363367898}, 'Test': {'acc': 0.5165319013229636}}
#
# ===== sage epoch 110 =====
# Loss: 1.3434226512908936
# {'Train': {'acc': 0.608647364774964}, 'Validation': {'acc': 0.582368535856908}, 'Test': {'acc': 0.5173960455115939}}
#
# ===== sage epoch 120 =====
# Loss: 1.3385258913040161
# {'Train': {'acc': 0.6087573261785113}, 'Validation': {'acc': 0.5807577435484412}, 'Test': {'acc': 0.5209966462975536}}
#
# ===== sage epoch 130 =====
# Loss: 1.310180425643921
# {'Train': {'acc': 0.6156409100405758}, 'Validation': {'acc': 0.592469545957918}, 'Test': {'acc': 0.539287698290229}}
#
# ===== sage epoch 140 =====
# Loss: 1.2926912307739258
# {'Train': {'acc': 0.6205891732002067}, 'Validation': {'acc': 0.5850867478774455}, 'Test': {'acc': 0.5185070880398329}}
#
# ===== sage epoch 150 =====
# Loss: 1.2761558294296265
# {'Train': {'acc': 0.6235801233766948}, 'Validation': {'acc': 0.588878821436961}, 'Test': {'acc': 0.5297409624920273}}
#
# ===== sage epoch 160 =====
# Loss: 1.2558988332748413
# {'Train': {'acc': 0.6289572360101604}, 'Validation': {'acc': 0.5917312661498708}, 'Test': {'acc': 0.5268604818632595}}
#
# ===== sage epoch 170 =====
# Loss: 1.2390828132629395
# {'Train': {'acc': 0.6346532367139134}, 'Validation': {'acc': 0.5940467800932917}, 'Test': {'acc': 0.5283830216241796}}
#
# ===== sage epoch 180 =====
# Loss: 1.241294503211975
# {'Train': {'acc': 0.6330368040817673}, 'Validation': {'acc': 0.5933756166314306}, 'Test': {'acc': 0.5317572989321647}}
#
# ===== sage epoch 190 =====
# Loss: 1.2173649072647095
# {'Train': {'acc': 0.6400963261895075}, 'Validation': {'acc': 0.5954562233632001}, 'Test': {'acc': 0.525193918070901}}
#
# ===== sage epoch 200 =====
# Loss: 1.201945424079895
# {'Train': {'acc': 0.6411519556635621}, 'Validation': {'acc': 0.5977046209604349}, 'Test': {'acc': 0.5331358146616464}}
#
# Finished training sage .

# %%
gat_curve = run_experiment(gnn_type="gat", num_epochs=num_epochs)
# Out:
# Started training gat...
#
# ===== gat epoch 10 =====
# Loss: 3.5006141662597656
# {'Train': {'acc': 0.07685202493924632}, 'Validation': {'acc': 0.14960233564884728}, 'Test': {'acc': 0.2209740139497562}}
#
# ===== gat epoch 20 =====
# Loss: 3.0430362224578857
# {'Train': {'acc': 0.17911613023828638}, 'Validation': {'acc': 0.07627772744051814}, 'Test': {'acc': 0.058741229965228486}}
#
# ===== gat epoch 30 =====
# Loss: 2.625784397125244
# {'Train': {'acc': 0.2820070155375463}, 'Validation': {'acc': 0.30695660928219065}, 'Test': {'acc': 0.28485895932349853}}
#
# ===== gat epoch 40 =====
# Loss: 2.3024280071258545
# {'Train': {'acc': 0.38018055662462474}, 'Validation': {'acc': 0.3917916708614383}, 'Test': {'acc': 0.3370573832890974}}
#
# ===== gat epoch 50 =====
# Loss: 2.050171375274658
# {'Train': {'acc': 0.42194389769191015}, 'Validation': {'acc': 0.4410550689620457}, 'Test': {'acc': 0.3935148036129457}}
#
# ===== gat epoch 60 =====
# Loss: 1.905479907989502
# {'Train': {'acc': 0.4740216184119374}, 'Validation': {'acc': 0.4763582670559415}, 'Test': {'acc': 0.43289508878052796}}
#
# ===== gat epoch 70 =====
# Loss: 1.7864210605621338
# {'Train': {'acc': 0.4975643549114261}, 'Validation': {'acc': 0.49884224302828956}, 'Test': {'acc': 0.4544781186346522}}
#
# ===== gat epoch 80 =====
# Loss: 1.6710647344589233
# {'Train': {'acc': 0.5305087914142136}, 'Validation': {'acc': 0.5222994060203362}, 'Test': {'acc': 0.4752793037466823}}
#
# ===== gat epoch 90 =====
# Loss: 1.5710368156433105
# {'Train': {'acc': 0.5459363763319075}, 'Validation': {'acc': 0.5310245310245311}, 'Test': {'acc': 0.4791268028722507}}
#
# ===== gat epoch 100 =====
# Loss: 1.500583291053772
# {'Train': {'acc': 0.5707986496739644}, 'Validation': {'acc': 0.5485754555521998}, 'Test': {'acc': 0.4920272411168035}}
#
# ===== gat epoch 110 =====
# Loss: 1.4591436386108398
# {'Train': {'acc': 0.5778911602027689}, 'Validation': {'acc': 0.5531058089197624}, 'Test': {'acc': 0.49583359051910375}}
#
# ===== gat epoch 120 =====
# Loss: 1.397916555404663
# {'Train': {'acc': 0.5972773556481675}, 'Validation': {'acc': 0.5632739353669586}, 'Test': {'acc': 0.4986317717013353}}
#
# ===== gat epoch 130 =====
# Loss: 1.408265471458435
# {'Train': {'acc': 0.6003892633685577}, 'Validation': {'acc': 0.571797711332595}, 'Test': {'acc': 0.5049688290846244}}
#
# ===== gat epoch 140 =====
# Loss: 1.3177478313446045
# {'Train': {'acc': 0.6139585005663012}, 'Validation': {'acc': 0.5739789925836437}, 'Test': {'acc': 0.5067588420467872}}
#
# ===== gat epoch 150 =====
# Loss: 1.2776496410369873
# {'Train': {'acc': 0.6239539921487558}, 'Validation': {'acc': 0.5725359911406424}, 'Test': {'acc': 0.5002777606320598}}
#
# ===== gat epoch 160 =====
# Loss: 1.2503502368927002
# {'Train': {'acc': 0.6263071661846692}, 'Validation': {'acc': 0.5870331219168429}, 'Test': {'acc': 0.5290414171964694}}
#
# ===== gat epoch 170 =====
# Loss: 1.2180289030075073
# {'Train': {'acc': 0.6410969749617884}, 'Validation': {'acc': 0.5881740998020067}, 'Test': {'acc': 0.523012982737691}}
#
# ===== gat epoch 180 =====
# Loss: 1.2061017751693726
# {'Train': {'acc': 0.6439999560154386}, 'Validation': {'acc': 0.5782073223933689}, 'Test': {'acc': 0.5057918235499866}}
#
# ===== gat epoch 190 =====
# Loss: 1.1517117023468018
# {'Train': {'acc': 0.6556008840896845}, 'Validation': {'acc': 0.5892479613409846}, 'Test': {'acc': 0.5209966462975536}}
#
# ===== gat epoch 200 =====
# Loss: 1.127066731452942
# {'Train': {'acc': 0.659988344091224}, 'Validation': {'acc': 0.5889794959562401}, 'Test': {'acc': 0.522251712857231}}
#
# Finished training gat .

# %%
plot_results(gcn_curve, sage_curve, gat_curve)
